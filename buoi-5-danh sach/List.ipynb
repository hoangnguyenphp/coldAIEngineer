# %%
# Empty list
a = []

# List with integer
b = [1, 2, 3, 4, 5]

# List of string
c = ["apple", "orange", "grape"]

# 
d = [1, 2, "apple"]

# list of list
e = [[1, 2, 3, 4, 5], ["apple", "orange", "grape"]]

#insert new element to a specific index of list.
numbers = [10, 20, 30, 40]
numbers.insert(2, 99)   # insert 99 at index 2
print(numbers)

# size of list
print(len(b))

#sort asc
c.sort
print(c)

# sort desc
c.sort(reverse=True)
print(c)

# reverse
d.reverse()
print(d)

# count an element in array
a = [2, 4, 2, 1, 3, 4, 2]
print(a.count(2))
print(a.count(5))

# get index of an element in array
print(a.index(2))
print(a.index(4))
# Out:
# 5
# ['apple', 'orange', 'grape']
# ['orange', 'grape', 'apple']
# ['apple', 2, 1]
# 3
# 0
# 0
# 1
