# %% [markdown]
# 1. Tung một xúc xắc: Hãy tính xác suất tung một con xúc xắc và đạt được kết quả
# cao hơn 4?
#
#     => 2/6
#
#
# 2. Tung hai xúc xắc: Hãy tính xác suất tung hai con xúc xắc và đạt được kết quả
# mà tổng 2 lần tung lớn hơn 3?
#
#     Tổng xác suất khi tung 2 đồng xu: 36
#     Các kết quả để tổng nhỏ hơn 3: 1-1; 1-2; 1-3 => 3
#
#     => Xác suất tung hai con xúc xắc và đạt được kết quả mà tổng 2 lần tung lớn hơn 3: 33/36
#
# 3. Tung đồng xu 5 lần: Hãy tính xác suất đạt 5 lần ngửa khi chúng ta tung đồng xu 5 lần liên tiếp
#     => (n!/k!​) x  p^k x (1−p)^n−k = 5!/5! x 0.5^5 x 5^0 = 0,03125 = 3,125%
#
# 4. Chất lượng của chiếc nồi: Trong siêu thị có 10 chiếc nồi với 2 chiếc nồi bị lỗi
# mà khách hàng không thể nhận ra. Một vị khách tiến hành mua 2 chiếc nồi. Hãy
# tính xác suất vị khách hàng này mua phải ít nhất 1 chiếc nồi bị lỗi?
#
#     => (2/10 x 2/9 x 1/9) = 4/810
#
#
# 5. Số chia hết cho 2 hoặc 5: Chọn ngẫu nhiên một số tự nhiên từ 1 đến 100, hãy
# tính xác suất số được chọn chia hết cho 2 hoặc 5
#     => 1/2 + 1/5 = 0,7 = 70%
#
# 6: Tung xúc xắc 7 lần: Tung 1 con xúc xắc 7 lần, hãy tính xác suất chúng ta đạt
# được đúng 3 lần xúc xắc có giá trị 6?
#     n = 7
#     k = 3
#     p = 1/6 =
#
#     => (n!/k!​) x  p^k x (1−p)^n−k = (7!/3! x 4!) x 0.16^3 x (1 - 0.16)^4 = 35 x 0.16^3 x 0.84^4 = 0,071 = 7,1%
