# %%
# Ex1: 
print("Hello, World!")


# Ex2:
name = input("Nhập tên: ")
print("Xin chào, ", name)


#
day = int(input("Nhập vào 1 ngày trong tuần: "))

if (day < 2 or day > 8):
    print("Invalid day.")
elif (day <=2 and day <= 6):
    print("Working day")
else: 
    print("Weekend")

#
a = int(input("Nhập vào số a: "))
b = int(input("Nhập vào số b: "))
c = int(input("Nhập vào số c: "))

max = a

if (max < b):
    max = b
if (max < c):
    max = c
print("Max: ", max)
# Out:
# Hello, World!
# Xin chào,  Jack
# Invalid day.
# Max:  40

# %%
payment = input('Enter payment amount: ')
if (payment >= 1000000):
    payment = payment * 0.9
elif (payment > 100000 )
