# %% [markdown]
# # Bài Tập Xây Dựng Mô Hình Random Forest: Dự đoán giá xe (CarDekho)
#
# ## Giới Thiệu
#
# Trong bài tập này, bạn sẽ xây dựng mô hình Random Forest để dự đoán giá bán của xe ô tô cũ dựa trên dữ liệu **cardekho_data.csv**. Mô hình Random Forest là tập hợp của nhiều cây quyết định, giúp giảm hiện tượng overfitting và cải thiện độ chính xác.

# %% [markdown]
# ## Bước 1: Nhập các thư viện và bộ dữ liệu
#
# Tương tự như bài tập Decision Tree, hãy nhập các thư viện cần thiết cho công việc này. Bạn sẽ cần `pandas`, `numpy`, `RandomForestRegressor`, `train_test_split`, `RandomizedSearchCV`, cùng với các hàm đánh giá mô hình và thư viện trực quan hóa.

# %% [markdown]
# ### Nhập các thư viện cần thiết

# %%
# Thư viện xử lý dữ liệu

### CODE CỦA BẠN ###

# Thư viện xây dựng và đánh giá mô hình Random Forest

### CODE CỦA BẠN ###

# Thư viện trực quan hóa dữ liệu

### CODE CỦA BẠN ###

# %% [markdown]
# ### Nhập bộ dữ liệu

# %%
# Đọc bộ dữ liệu vào DataFrame df_original

### CODE CỦA BẠN ###

# Gợi ý:
# df_original = pd.read_csv('cardekho_data.csv')

# %% [markdown]
# ### Kiểm tra 10 dòng đầu tiên của bộ dữ liệu

# %%
# Hiển thị 10 dòng đầu tiên

### CODE CỦA BẠN ###

# %% [markdown]
# ## Bước 2: Khám phá, làm sạch và chuẩn bị dữ liệu cho mô hình

# %% [markdown]
# ### Khám phá bộ dữ liệu
#
# - Kiểm tra kiểu dữ liệu của từng cột.
# - Kiểm tra kích thước của DataFrame.
# - In mô tả thống kê cho các cột số.

# %%
# Kiểm tra kiểu dữ liệu, kích thước và mô tả thống kê

### CODE CỦA BẠN ###

# %% [markdown]
# ### Kiểm tra các nhóm của các biến phân loại
#
# Hãy in ra danh sách các giá trị duy nhất của các trường `Fuel_Type`, `Seller_Type`, `Transmission` và `Owner`.

# %%
# In các giá trị duy nhất của các biến phân loại

### CODE CỦA BẠN ###

# %% [markdown]
# ### Kiểm tra phân bố biến mục tiêu
#
# Hãy kiểm tra phân bố của biến `Selling_Price` bằng mô tả thống kê và biểu đồ.

# %%
# Kiểm tra phân bố của biến Selling_Price

### CODE CỦA BẠN ###

# %% [markdown]
# ### Kiểm tra dữ liệu trống

# %%
# Đếm số giá trị trống trong từng cột

### CODE CỦA BẠN ###

# %% [markdown]
# ### Tạo biến tuổi xe và xử lý cột `Car_Name`
#
# - Tạo biến `Age` bằng `2025 - Year` rồi bỏ cột `Year`.
# - Do có quá nhiều tên xe khác nhau, hãy cân nhắc loại bỏ cột `Car_Name`.

# %%
# Tạo biến Age và loại bỏ cột Car_Name và Year

### CODE CỦA BẠN ###

# %% [markdown]
# ### Tạo biến giả cho các biến phân loại

# %%
# One-hot encode các cột Fuel_Type, Seller_Type, Transmission, Owner

### CODE CỦA BẠN ###

# %% [markdown]
# ### Tạo bộ dữ liệu train và test
#
# Chia dữ liệu thành tập train và test theo tỷ lệ 75/25, với biến mục tiêu là `Selling_Price`.

# %%
# Tách X và y, sau đó chia thành train và test

### CODE CỦA BẠN ###

# %% [markdown]
# ## Bước 3: Xây dựng mô hình Random Forest

# %% [markdown]
# ### Huấn luyện mô hình Random Forest
#
# Tạo một `RandomForestRegressor` với `random_state = 8` và huấn luyện mô hình trên tập train. Sau đó, dự đoán trên tập test.

# %%
# Tạo và huấn luyện mô hình RandomForestRegressor

### CODE CỦA BẠN ###

# %% [markdown]
# **Câu hỏi:** Ưu điểm của mô hình Random Forest so với Decision Tree là gì?

# %% [markdown]
# [Hãy viết câu trả lời của bạn tại đây. Hãy nhấn hai lần vào ô này để chỉnh sửa]

# %% [markdown]
# ## Bước 4: Kết quả và đánh giá mô hình

# %% [markdown]
# Tương tự Decision Tree, hãy tính các chỉ số **MSE**, **RMSE**, **MAE** và **R² Score** trên tập test để đánh giá mô hình Random Forest.

# %%
# Tính toán các chỉ số đánh giá mô hình Random Forest

### CODE CỦA BẠN ###

# %% [markdown]
# ### Trực quan hóa kết quả dự đoán
#
# Vẽ biểu đồ scatter giữa giá thực tế và giá dự đoán trên tập test để quan sát mức độ khớp giữa mô hình và dữ liệu.

# %%
# Vẽ biểu đồ scatter giữa y_test và y_pred

### CODE CỦA BẠN ###

# %% [markdown]
# **Câu hỏi:** Hãy so sánh kết quả đánh giá của mô hình Random Forest và Decision Tree bạn đã thực hiện. Mô hình nào cho kết quả tốt hơn? Vì sao?

# %% [markdown]
# [Hãy viết câu trả lời của bạn tại đây. Hãy nhấn hai lần vào ô này để chỉnh sửa]

# %% [markdown]
# ## Bước 5: Tính toán độ quan trọng của các biến độc lập

# %% [markdown]
# Random Forest cũng cung cấp thuộc tính `feature_importances_`. Hãy tạo bảng và biểu đồ thể hiện mức độ quan trọng của từng biến đầu vào trong mô hình.

# %%
# Tính toán và trực quan hóa độ quan trọng của các biến

### CODE CỦA BẠN ###

# %% [markdown]
# ## Bước 6: Tune các hyperparameter

# %% [markdown]
# Để cải thiện mô hình, chúng ta sẽ sử dụng `RandomizedSearchCV` để tìm kiếm ngẫu nhiên các giá trị tốt nhất cho một số tham số quan trọng, ví dụ `n_estimators`, `max_depth`, `min_samples_leaf`, `max_features`. Sử dụng kiểm chứng chéo (`cv=5`) và `random_state=8`.
#
# Sự khác biệt giữa `RandomizedSearchCV` và `GridSearchCV` là gì?

# %% [markdown]
# [Hãy viết câu trả lời của bạn tại đây. Hãy nhấn hai lần vào ô này để chỉnh sửa]

# %%
# Thiết lập không gian tham số và thực hiện RandomizedSearchCV

### CODE CỦA BẠN ###

# %% [markdown]
# ### Đánh giá mô hình tối ưu
#
# Sau khi tìm được mô hình tốt nhất, hãy in ra các tham số tối ưu và tính lại các chỉ số MSE, RMSE, MAE và R² trên tập test.

# %%
# In tham số tối ưu và đánh giá mô hình mới

### CODE CỦA BẠN ###

# %% [markdown]
# **Câu hỏi:** Việc tune hyperparameter bằng RandomizedSearchCV có cải thiện mô hình nhiều không? Hãy giải thích.

# %% [markdown]
# [Hãy viết câu trả lời của bạn tại đây. Hãy nhấn hai lần vào ô này để chỉnh sửa]
